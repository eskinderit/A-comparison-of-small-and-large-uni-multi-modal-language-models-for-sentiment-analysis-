# %% [markdown]
# ## Machine learning

# %%
import os
import numpy as np
import opensmile
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

# Emotion labels
emotion_labels = {
    'W': 'Anger',
    'L': 'Boredom',
    'E': 'Disgust',
    'A': 'Anxiety/Fear',
    'F': 'Happiness',
    'T': 'Sadness',
    'N': 'Neutral'
}

# Feature extraction
def extract_audio_features(file_path):
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.GeMAPSv01b,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
    features = smile.process_file(file_path)
    return features.values

# Load data
data_folder = "Emo-DB-database"
file_list = os.listdir(data_folder)


print(f"Total files in the folder: {len(file_list)}")
print(f"File list: {file_list}\n")



data = []
labels = []



for file_name in file_list:
    emotion_code = file_name[5]
    print(f"Processing {file_name}, emotion_code: {emotion_code}")  # Add this line
    if emotion_code in emotion_labels:
        file_path = os.path.join(data_folder, file_name)
        features = extract_audio_features(file_path)
        print(f"Features shape for {file_name}: {features.shape}")
        data.append(features)
        labels.append(emotion_code)
    else:
        print(f"Skipping {file_name}, emotion_code: {emotion_code}")  # Add this line

data = np.vstack(data)
labels = np.array(labels)

# Preprocessing
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Train a classifier
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)

# Evaluate the model
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred, target_names=emotion_labels.values()))
# Out:
# Total files in the folder: 535
# File list: ['03a01Fa.wav', '03a01Nc.wav', '03a01Wa.wav', '03a02Fc.wav', '03a02Nc.wav', '03a02Ta.wav', '03a02Wb.wav', '03a02Wc.wav', '03a04Ad.wav', '03a04Fd.wav', '03a04Lc.wav', '03a04Nc.wav', '03a04Ta.wav', '03a04Wc.wav', '03a05Aa.wav', '03a05Fc.wav', '03a05Nd.wav', '03a05Tc.wav', '03a05Wa.wav', '03a05Wb.wav', '03a07Fa.wav', '03a07Fb.wav', '03a07La.wav', '03a07Nc.wav', '03a07Wc.wav', '03b01Fa.wav', '03b01Lb.wav', '03b01Nb.wav', '03b01Td.wav', '03b01Wa.wav', '03b01Wc.wav', '03b02Aa.wav', '03b02La.wav', '03b02Na.wav', '03b02Tb.wav', '03b02Wb.wav', '03b03Nb.wav', '03b03Tc.wav', '03b03Wc.wav', '03b09La.wav', '03b09Nc.wav', '03b09Tc.wav', '03b09Wa.wav', '03b10Ab.wav', '03b10Ec.wav', '03b10Na.wav', '03b10Nc.wav', '03b10Wb.wav', '03b10Wc.wav', '08a01Ab.wav', '08a01Fd.wav', '08a01Lc.wav', '08a01Na.wav', '08a01Wa.wav', '08a01Wc.wav', '08a02Ab.wav', '08a02Ac.wav', '08a02Fe.wav', '08a02La.wav', '08a02Na.wav', '08a02Tb.wav', '08a02Wc.wav', '08a04Ff.wav', '08a04La.wav', '08a04Nc.wav', '08a04Tb.wav', '08a04Wc.wav', '08a05Fe.wav', '08a05Lc.wav', '08a05Nb.wav', '08a05Ta.wav', '08a05Wa.wav', '08a07Fd.wav', '08a07La.wav', '08a07Na.wav', '08a07Ta.wav', '08a07Tb.wav', '08a07Wc.wav', '08b01Aa.wav', '08b01Fd.wav', '08b01Fe.wav', '08b01Lb.wav', '08b01Na.wav', '08b01Wa.wav', '08b02Ff.wav', '08b02La.wav', '08b02Nb.wav', '08b02Tc.wav', '08b02Wd.wav', '08b03Fe.wav', '08b03Lc.wav', '08b03Nb.wav', '08b03Tc.wav', '08b03Wd.wav', '08b09Ab.wav', '08b09Fd.wav', '08b09Lc.wav', '08b09Nb.wav', '08b09Tb.wav', '08b09Wa.wav', '08b09Wc.wav', '08b10Aa.wav', '08b10Fd.wav', '08b10La.wav', '08b10Nc.wav', '08b10Tc.wav', '08b10Wa.wav', '09a01Ea.wav', '09a01Fa.wav', '09a01Nb.wav', '09a01Wb.wav', '09a02Ea.wav', '09a02Eb.wav', '09a02La.wav', '09a02Wb.wav', '09a04Fd.wav', '09a04La.wav', '09a04Nb.wav', '09a04Wa.wav', '09a05Ed.wav', '09a05Lc.wav', '09a05Nb.wav', '09a05Tb.wav', '09a05Wb.wav', '09a05Wc.wav', '09a07Eb.wav', '09a07Na.wav', '09a07Ta.wav', '09a07Wb.wav', '09a07Wd.wav', '09b01Ea.wav', '09b01Na.wav', '09b01Wb.wav', '09b02Na.wav', '09b02Tb.wav', '09b02Wc.wav', '09b02Wd.wav', '09b03Ed.wav', '09b03Fa.wav', '09b03Fd.wav', '09b03Lb.wav', '09b03Nb.wav', '09b03Ta.wav', '09b03Wb.wav', '09b09Ea.wav', '09b09Nd.wav', '09b09Wa.wav', '09b10Aa.wav', '09b10Nd.wav', '09b10Wa.wav', '10a01Ac.wav', '10a01Nb.wav', '10a01Wa.wav', '10a02Ab.wav', '10a02Fa.wav', '10a02Lb.wav', '10a02Na.wav', '10a02Wa.wav', '10a04Fd.wav', '10a04Nb.wav', '10a04Wa.wav', '10a04Wb.wav', '10a05Aa.wav', '10a05Ld.wav', '10a05Tb.wav', '10a05Wb.wav', '10a07Aa.wav', '10a07Ad.wav', '10a07La.wav', '10a07Ta.wav', '10a07Wb.wav', '10b01Aa.wav', '10b01Ea.wav', '10b01Fa.wav', '10b01Lb.wav', '10b02Aa.wav', '10b02La.wav', '10b02Na.wav', '10b02Wb.wav', '10b03La.wav', '10b03Tb.wav', '10b03Wb.wav', '10b09Ad.wav', '10b09Lb.wav', '10b09Wb.wav', '10b10Fc.wav', '10b10Lc.wav', '10b10Wa.wav', '11a01Aa.wav', '11a01Ab.wav', '11a01Ld.wav', '11a01Nd.wav', '11a01Wc.wav', '11a02Ec.wav', '11a02Fb.wav', '11a02Ld.wav', '11a02Nc.wav', '11a02Tc.wav', '11a02Wc.wav', '11a04Ac.wav', '11a04Fd.wav', '11a04Nd.wav', '11a04Wc.wav', '11a05Ad.wav', '11a05Fb.wav', '11a05Fc.wav', '11a05Lc.wav', '11a05Na.wav', '11a05Td.wav', '11a05Wd.wav', '11a07Ac.wav', '11a07Ld.wav', '11a07Ta.wav', '11a07Wc.wav', '11b01Ab.wav', '11b01Eb.wav', '11b01Fc.wav', '11b01Lb.wav', '11b01Nc.wav', '11b01Wd.wav', '11b02Ab.wav', '11b02Fd.wav', '11b02Na.wav', '11b02Td.wav', '11b02Wb.wav', '11b03Fc.wav', '11b03Lc.wav', '11b03Nb.wav', '11b03Td.wav', '11b03Wa.wav', '11b03Wb.wav', '11b09Ad.wav', '11b09Fd.wav', '11b09Ld.wav', '11b09Na.wav', '11b09Td.wav', '11b09Wa.wav', '11b10Ad.wav', '11b10Ae.wav', '11b10Ld.wav', '11b10Nc.wav', '11b10Td.wav', '11b10Wa.wav', '12a01Fb.wav', '12a01Lb.wav', '12a01Nb.wav', '12a01Wc.wav', '12a02Ac.wav', '12a02Ec.wav', '12a02Nb.wav', '12a02Wa.wav', '12a02Wc.wav', '12a04Wc.wav', '12a05Ab.wav', '12a05Lb.wav', '12a05Nd.wav', '12a05Ta.wav', '12a05Wb.wav', '12a07Ac.wav', '12a07La.wav', '12a07Wa.wav', '12b01Ta.wav', '12b01Wa.wav', '12b02Ad.wav', '12b02Ea.wav', '12b02Fb.wav' ...
#
# Processing 03a01Fa.wav, emotion_code: F
# Features shape for 03a01Fa.wav: (1, 62)
# Processing 03a01Nc.wav, emotion_code: N
# Features shape for 03a01Nc.wav: (1, 62)
# Processing 03a01Wa.wav, emotion_code: W
# Features shape for 03a01Wa.wav: (1, 62)
# Processing 03a02Fc.wav, emotion_code: F
# Features shape for 03a02Fc.wav: (1, 62)
# Processing 03a02Nc.wav, emotion_code: N
# Features shape for 03a02Nc.wav: (1, 62)
# Processing 03a02Ta.wav, emotion_code: T
# Features shape for 03a02Ta.wav: (1, 62)
# Processing 03a02Wb.wav, emotion_code: W
# Features shape for 03a02Wb.wav: (1, 62)
# Processing 03a02Wc.wav, emotion_code: W
# Features shape for 03a02Wc.wav: (1, 62)
# Processing 03a04Ad.wav, emotion_code: A
# Features shape for 03a04Ad.wav: (1, 62)
# Processing 03a04Fd.wav, emotion_code: F
# Features shape for 03a04Fd.wav: (1, 62)
# Processing 03a04Lc.wav, emotion_code: L
# Features shape for 03a04Lc.wav: (1, 62)
# Processing 03a04Nc.wav, emotion_code: N
# Features shape for 03a04Nc.wav: (1, 62)
# Processing 03a04Ta.wav, emotion_code: T
# Features shape for 03a04Ta.wav: (1, 62)
# Processing 03a04Wc.wav, emotion_code: W
# Features shape for 03a04Wc.wav: (1, 62)
# Processing 03a05Aa.wav, emotion_code: A
# Features shape for 03a05Aa.wav: (1, 62)
# Processing 03a05Fc.wav, emotion_code: F
# Features shape for 03a05Fc.wav: (1, 62)
# Processing 03a05Nd.wav, emotion_code: N
# Features shape for 03a05Nd.wav: (1, 62)
# Processing 03a05Tc.wav, emotion_code: T
# Features shape for 03a05Tc.wav: (1, 62)
# Processing 03a05Wa.wav, emotion_code: W
# Features shape for 03a05Wa.wav: (1, 62)
# Processing 03a05Wb.wav, emotion_code: W
# Features shape for 03a05Wb.wav: (1, 62)
# Processing 03a07Fa.wav, emotion_code: F
# Features shape for 03a07Fa.wav: (1, 62)
# Processing 03a07Fb.wav, emotion_code: F
# Features shape for 03a07Fb.wav: (1, 62)
# Processing 03a07La.wav, emotion_code: L
# Features shape for 03a07La.wav: (1, 62)
# Processing 03a07Nc.wav, emotion_code: N
# Features shape for 03a07Nc.wav: (1, 62)
# Processing 03a07Wc.wav, emotion_code: W
# Features shape for 03a07Wc.wav: (1, 62)
# Processing 03b01Fa.wav, emotion_code: F
# Features shape for 03b01Fa.wav: (1, 62)
# Processing 03b01Lb.wav, emotion_code: L
# Features shape for 03b01Lb.wav: (1, 62)
# Processing 03b01Nb.wav, emotion_code: N
# Features shape for 03b01Nb.wav: (1, 62)
# Processing 03b01Td.wav, emotion_code: T
# Features shape for 03b01Td.wav: (1, 62)
# Processing 03b01Wa.wav, emotion_code: W
# Features shape for 03b01Wa.wav: (1, 62)
# Processing 03b01Wc.wav, emotion_code: W
# Features shape for 03b01Wc.wav: (1, 62)
# Processing 03b02Aa.wav, emotion_code: A
# Features shape for 03b02Aa.wav: (1, 62)
# Processing 03b02La.wav, emotion_code: L
# Features shape for 03b02La.wav: (1, 62)
# Processing 03b02Na.wav, emotion_code: N
# Features shape for 03b02Na.wav: (1, 62)
# Processing 03b02Tb.wav, emotion_code: T
# Features shape for 03b02Tb.wav: (1, 62)
# Processing 03b02Wb.wav, emotion_code: W
# Features shape for 03b02Wb.wav: (1, 62)
# Processing 03b03Nb.wav, emotion_code: N
# Features shape for 03b03Nb.wav: (1, 62)
# Processing 03b03Tc.wav, emotion_code: T
# Features shape for 03b03Tc.wav: (1, 62)
# Processing 03b03Wc.wav, emotion_code: W
# Features shape for 03b03Wc.wav: (1, 62)
# Processing 03b09La.wav, emotion_code: L
# Features shape for 03b09La.wav: (1, 62)
# Processing 03b09Nc.wav, emotion_code: N
# Features shape for 03b09Nc.wav: (1, 62)
# Processing 03b09Tc.wav, emotion_code: T
# Features shape for 03b09Tc.wav: (1, 62)
# Processing 03b09Wa.wav, emotion_code: W
# Features shape for 03b09Wa.wav: (1, 62)
# Processing 03b10Ab.wav, emotion_code: A
# Features shape for 03b10Ab.wav: (1, 62)
# Processing 03b10Ec.wav, emotion_code: E
# Features shape for 03b10Ec.wav: (1, 62)
# Processing 03b10Na.wav, emotion_code: N
# Features shape for 03b10Na.wav: (1, 62)
# Processing 03b10Nc.wav, emotion_code: N
# Features shape for 03b10Nc.wav: (1, 62)
# Processing 03b10Wb.wav, emotion_code: W
# Features shape for 03b10Wb.wav: (1, 62)
# Processing 03b10Wc.wav, emotion_code: W
# Features shape for 03b10Wc.wav: (1, 62)
# Processing 08a01Ab.wav, emotion_code: A
# Features shape for 08a01Ab.wav: (1, 62)
# Processing 08a01Fd.wav, emotion_code: F
# Features shape for 08a01Fd.wav: (1, 62)
# Processing 08a01Lc.wav, emotion_code: L
# Features shape for 08a01Lc.wav: (1, 62)
# Processing 08a01Na.wav, emotion_code: N
# Features shape for 08a01Na.wav: (1, 62)
# Processing 08a01Wa.wav, emotion_code: W
# Features shape for 08a01Wa.wav: (1, 62)
# Processing 08a01Wc.wav, emotion_code: W
# Features shape for 08a01Wc.wav: (1, 62)
# Processing 08a02Ab.wav, emotion_code: A
# Features shape for 08a02Ab.wav: (1, 62)
# Processing 08a02Ac.wav, emotion_code: A
# Features shape for 08a02Ac.wav: (1, 62)
# Processing 08a02Fe.wav, emotion_code: F
# Features shape for 08a02Fe.wav: (1, 62)
# Processing 08a02La.wav, emotion_code: L
# Features shape for 08a02La.wav: (1, 62)
# Processing 08a02Na.wav, emotion_code: N
# Features shape for 08a02Na.wav: (1, 62)
# Processing 08a02Tb.wav, emotion_code: T
# Features shape for 08a02Tb.wav: (1, 62)
# Processing 08a02Wc.wav, emotion_code: W
# Features shape for 08a02Wc.wav: (1, 62)
# Processing 08a04Ff.wav, emotion_code: F
# Features shape for 08a04Ff.wav: (1, 62)
# Processing 08a04La.wav, emotion_code: L
# Features shape for 08a04La.wav: (1, 62)
# Processing 08a04Nc.wav, emotion_code: N
# Features shape for 08a04Nc.wav: (1, 62)
# Processing 08a04Tb.wav, emotion_code: T
# Features shape for 08a04Tb.wav: (1, 62)
# Processing 08a04Wc.wav, emotion_code: W
# Features shape for 08a04Wc.wav: (1, 62)
# Processing 08a05Fe.wav, emotion_code: F
# Features shape for 08a05Fe.wav: (1, 62)
# Processing 08a05Lc.wav, emotion_code: L
# Features shape for 08a05Lc.wav: (1, 62)
# Processing 08a05Nb.wav, emotion_code: N
# Features shape for 08a05Nb.wav: (1, 62)
# Processing 08a05Ta.wav, emotion_code: T
# Features shape for 08a05Ta.wav: (1, 62)
# Processing 08a05Wa.wav, emotion_code: W
# Features shape for 08a05Wa.wav: (1, 62)
# Processing 08a07Fd.wav, emotion_code: F
# Features shape for 08a07Fd.wav: (1, 62)
# Processing 08a07La.wav, emotion_code: L
# Features shape for 08a07La.wav: (1, 62)
# Processing 08a07Na.wav, emotion_code: N
# Features shape for 08a07Na.wav: (1, 62)
# Processing 08a07Ta.wav, emotion_code: T
# Features shape for 08a07Ta.wav: (1, 62)
# Processing 08a07Tb.wav, emotion_code: T
# Features shape for 08a07Tb.wav: (1, 62)
# Processing 08a07Wc.wav, emotion_code: W
# Features shape for 08a07Wc.wav: (1, 62)
# Processing 08b01Aa.wav, emotion_code: A
# Features shape for 08b01Aa.wav: (1, 62)
# Processing 08b01Fd.wav, emotion_code: F
# Features shape for 08b01Fd.wav: (1, 62)
# Processing 08b01Fe.wav, emotion_code: F
# Features shape for 08b01Fe.wav: (1, 62)
# Processing 08b01Lb.wav, emotion_code: L
# Features shape for 08b01Lb.wav: (1, 62)
# Processing 08b01Na.wav, emotion_code: N
# Features shape for 08b01Na.wav: (1, 62)
# Processing 08b01Wa.wav, emotion_code: W
# Features shape for 08b01Wa.wav: (1, 62)
# Processing 08b02Ff.wav, emotion_code: F
# Features shape for 08b02Ff.wav: (1, 62)
# Processing 08b02La.wav, emotion_code: L
# Features shape for 08b02La.wav: (1, 62)
# Processing 08b02Nb.wav, emotion_code: N
# Features shape for 08b02Nb.wav: (1, 62)
# Processing 08b02Tc.wav, emotion_code: T
# Features shape for 08b02Tc.wav: (1, 62)
# Processing 08b02Wd.wav, emotion_code: W
# Features shape for 08b02Wd.wav: (1, 62)
# Processing 08b03Fe.wav, emotion_code: F
# Features shape for 08b03Fe.wav: (1, 62)
# Processing 08b03Lc.wav, emotion_code: L
# Features shape for 08b03Lc.wav: (1, 62)
# Processing 08b03Nb.wav, emotion_code: N
# Features shape for 08b03Nb.wav: (1, 62)
# Processing 08b03Tc.wav, emotion_code: T
# Features shape for 08b03Tc.wav: (1, 62)
# Processing 08b03Wd.wav, emotion_code: W
# Features shape for 08b03Wd.wav: (1, 62)
# Processing 08b09Ab.wav, emotion_code: A
# Features shape for 08b09Ab.wav: (1, 62)
# Processing 08b09Fd.wav, emotion_code: F
# Features shape for 08b09Fd.wav: (1, 62)
# Processing 08b09Lc.wav, emotion_code: L
# Features shape for 08b09Lc.wav: (1, 62)
# Processing 08b09Nb.wav, emotion_code: N
# Features shape for 08b09Nb.wav: (1, 62)
# Processing 08b09Tb.wav, emotion_code: T
# Features shape for 08b09Tb.wav: (1, 62)
# Processing 08b09Wa.wav, emotion_code: W
# Features shape for 08b09Wa.wav: (1, 62)
# Processing 08b09Wc.wav, emotion_code: W
# Features shape for 08b09Wc.wav: (1, 62)
# Processing 08b10Aa.wav, emotion_code: A
# Features shape for 08b10Aa.wav: (1, 62)
# Processing 08b10Fd.wav, emotion_code: F
# Features shape for 08b10Fd.wav: (1, 62)
# Processing 08b10La.wav, emotion_code: L
# Features shape for 08b10La.wav: (1, 62)
# Processing 08b10Nc.wav, emotion_code: N
# Features shape for 08b10Nc.wav: (1, 62)
# Processing 08b10Tc.wav, emotion_code: T
# Features shape for 08b10Tc.wav: (1, 62)
# Processing 08b10Wa.wav, emotion_code: W
# Features shape for 08b10Wa.wav: (1, 62)
# Processing 09a01Ea.wav, emotion_code: E
# Features shape for 09a01Ea.wav: (1, 62)
# Processing 09a01Fa.wav, emotion_code: F
# Features shape for 09a01Fa.wav: (1, 62)
# Processing 09a01Nb.wav, emotion_code: N
# Features shape for 09a01Nb.wav: (1, 62)
# Processing 09a01Wb.wav, emotion_code: W
# Features shape for 09a01Wb.wav: (1, 62)
# Processing 09a02Ea.wav, emotion_code: E
# Features shape for 09a02Ea.wav: (1, 62)
# Processing 09a02Eb.wav, emotion_code: E
# Features shape for 09a02Eb.wav: (1, 62)
# Processing 09a02La.wav, emotion_code: L
# Features shape for 09a02La.wav: (1, 62)
# Processing 09a02Wb.wav, emotion_code: W
# Features shape for 09a02Wb.wav: (1, 62)
# Processing 09a04Fd.wav, emotion_code: F
# Features shape for 09a04Fd.wav: (1, 62)
# Processing 09a04La.wav, emotion_code: L
# Features shape for 09a04La.wav: (1, 62)
# Processing 09a04Nb.wav, emotion_code: N
# Features shape for 09a04Nb.wav: (1, 62)
# Processing 09a04Wa.wav, emotion_code: W
# Features shape for 09a04Wa.wav: (1, 62)
# Processing 09a05Ed.wav, emotion_code: E
# Features shape for 09a05Ed.wav: (1, 62)
# Processing 09a05Lc.wav, emotion_code: L
# Features shape for 09a05Lc.wav: (1, 62)
# Processing 09a05Nb.wav, emotion_code: N
# Features shape for 09a05Nb.wav: (1, 62)
# Processing 09a05Tb.wav, emotion_code: T
# Features shape for 09a05Tb.wav: (1, 62)
# Processing 09a05Wb.wav, emotion_code: W
# Features shape for 09a05Wb.wav: (1, 62)
# Processing 09a05Wc.wav, emotion_code: W
# Features shape for 09a05Wc.wav: (1, 62)
# Processing 09a07Eb.wav, emotion_code: E
# Features shape for 09a07Eb.wav: (1, 62)
# Processing 09a07Na.wav, emotion_code: N
# Features shape for 09a07Na.wav: (1, 62)
# Processing 09a07Ta.wav, emotion_code: T
# Features shape for 09a07Ta.wav: (1, 62)
# Processing 09a07Wb.wav, emotion_code: W
# Features shape for 09a07Wb.wav: (1, 62)
# Processing 09a07Wd.wav, emotion_code: W
# Features shape for 09a07Wd.wav: (1, 62)
# Processing 09b01Ea.wav, emotion_code: E
# Features shape for 09b01Ea.wav: (1, 62)
# Processing 09b01Na.wav, emotion_code: N
# Features shape for 09b01Na.wav: (1, 62)
# Processing 09b01Wb.wav, emotion_code: W
# Features shape for 09b01Wb.wav: (1, 62)
# Processing 09b02Na.wav, emotion_code: N
# Features shape for 09b02Na.wav: (1, 62)
# Processing 09b02Tb.wav, emotion_code: T
# Features shape for 09b02Tb.wav: (1, 62)
# Processing 09b02Wc.wav, emotion_code: W
# Features shape for 09b02Wc.wav: (1, 62)
# Processing 09b02Wd.wav, emotion_code: W
# Features shape for 09b02Wd.wav: (1, 62)
# Processing 09b03Ed.wav, emotion_code: E
# Features shape for 09b03Ed.wav: (1, 62)
# Processing 09b03Fa.wav, emotion_code: F
# Features shape for 09b03Fa.wav: (1, 62)
# Processing 09b03Fd.wav, emotion_code: F
# Features shape for 09b03Fd.wav: (1, 62)
# Processing 09b03Lb.wav, emotion_code: L
# Features shape for 09b03Lb.wav: (1, 62)
# Processing 09b03Nb.wav, emotion_code: N
# Features shape for 09b03Nb.wav: (1, 62)
# Processing 09b03Ta.wav, emotion_code: T
# Features shape for 09b03Ta.wav: (1, 62)
# Processing 09b03Wb.wav, emotion_code: W
# Features shape for 09b03Wb.wav: (1, 62)
# Processing 09b09Ea.wav, emotion_code: E
# Features shape for 09b09Ea.wav: (1, 62)
# Processing 09b09Nd.wav, emotion_code: N
# Features shape for 09b09Nd.wav: (1, 62)
# Processing 09b09Wa.wav, emotion_code: W
# Features shape for 09b09Wa.wav: (1, 62)
# Processing 09b10Aa.wav, emotion_code: A
# Features shape for 09b10Aa.wav: (1, 62)
# Processing 09b10Nd.wav, emotion_code: N
# Features shape for 09b10Nd.wav: (1, 62)
# Processing 09b10Wa.wav, emotion_code: W
# Features shape for 09b10Wa.wav: (1, 62)
# Processing 10a01Ac.wav, emotion_code: A
# Features shape for 10a01Ac.wav: (1, 62)
# Processing 10a01Nb.wav, emotion_code: N
# Features shape for 10a01Nb.wav: (1, 62)
# Processing 10a01Wa.wav, emotion_code: W
# Features shape for 10a01Wa.wav: (1, 62)
# Processing 10a02Ab.wav, emotion_code: A
# Features shape for 10a02Ab.wav: (1, 62)
# Processing 10a02Fa.wav, emotion_code: F
# Features shape for 10a02Fa.wav: (1, 62)
# Processing 10a02Lb.wav, emotion_code: L
# Features shape for 10a02Lb.wav: (1, 62)
# Processing 10a02Na.wav, emotion_code: N
# Features shape for 10a02Na.wav: (1, 62)
# Processing 10a02Wa.wav, emotion_code: W
# Features shape for 10a02Wa.wav: (1, 62)
# Processing 10a04Fd.wav, emotion_code: F
# Features shape for 10a04Fd.wav: (1, 62)
# Processing 10a04Nb.wav, emotion_code: N
# Features shape for 10a04Nb.wav: (1, 62)
# Processing 10a04Wa.wav, emotion_code: W
# Features shape for 10a04Wa.wav: (1, 62)
# Processing 10a04Wb.wav, emotion_code: W
# Features shape for 10a04Wb.wav: (1, 62)
# Processing 10a05Aa.wav, emotion_code: A
# Features shape for 10a05Aa.wav: (1, 62)
# Processing 10a05Ld.wav, emotion_code: L
# Features shape for 10a05Ld.wav: (1, 62)
# Processing 10a05Tb.wav, emotion_code: T
# Features shape for 10a05Tb.wav: (1, 62)
# Processing 10a05Wb.wav, emotion_code: W
# Features shape for 10a05Wb.wav: (1, 62)
# Processing 10a07Aa.wav, emotion_code: A
# Features shape for 10a07Aa.wav: (1, 62)
# Processing 10a07Ad.wav, emotion_code: A
# Features shape for 10a07Ad.wav: (1, 62)
# Processing 10a07La.wav, emotion_code: L
# Features shape for 10a07La.wav: (1, 62)
# Processing 10a07Ta.wav, emotion_code: T
# Features shape for 10a07Ta.wav: (1, 62)
# Processing 10a07Wb.wav, emotion_code: W
# Features shape for 10a07Wb.wav: (1, 62)
# Processing 10b01Aa.wav, emotion_code: A
# Features shape for 10b01Aa.wav: (1, 62)
# Processing 10b01Ea.wav, emotion_code: E
# Features shape for 10b01Ea.wav: (1, 62)
# Processing 10b01Fa.wav, emotion_code: F
# Features shape for 10b01Fa.wav: (1, 62)
# Processing 10b01Lb.wav, emotion_code: L
# Features shape for 10b01Lb.wav: (1, 62)
# Processing 10b02Aa.wav, emotion_code: A
# Features shape for 10b02Aa.wav: (1, 62)
# Processing 10b02La.wav, emotion_code: L
# Features shape for 10b02La.wav: (1, 62)
# Processing 10b02Na.wav, emotion_code: N
# Features shape for 10b02Na.wav: (1, 62)
# Processing 10b02Wb.wav, emotion_code: W
# Features shape for 10b02Wb.wav: (1, 62)
# Processing 10b03La.wav, emotion_code: L
# Features shape for 10b03La.wav: (1, 62)
# Processing 10b03Tb.wav, emotion_code: T
# Features shape for 10b03Tb.wav: (1, 62)
# Processing 10b03Wb.wav, emotion_code: W
# Features shape for 10b03Wb.wav: (1, 62)
# Processing 10b09Ad.wav, emotion_code: A
# Features shape for 10b09Ad.wav: (1, 62)
# Processing 10b09Lb.wav, emotion_code: L
# Features shape for 10b09Lb.wav: (1, 62)
# Processing 10b09Wb.wav, emotion_code: W
# Features shape for 10b09Wb.wav: (1, 62)
# Processing 10b10Fc.wav, emotion_code: F
# Features shape for 10b10Fc.wav: (1, 62)
# Processing 10b10Lc.wav, emotion_code: L
# Features shape for 10b10Lc.wav: (1, 62)
# Processing 10b10Wa.wav, emotion_code: W
# Features shape for 10b10Wa.wav: (1, 62)
# Processing 11a01Aa.wav, emotion_code: A
# Features shape for 11a01Aa.wav: (1, 62)
# Processing 11a01Ab.wav, emotion_code: A
# Features shape for 11a01Ab.wav: (1, 62)
# Processing 11a01Ld.wav, emotion_code: L
# Features shape for 11a01Ld.wav: (1, 62)
# Processing 11a01Nd.wav, emotion_code: N
# Features shape for 11a01Nd.wav: (1, 62)
# Processing 11a01Wc.wav, emotion_code: W
# Features shape for 11a01Wc.wav: (1, 62)
# Processing 11a02Ec.wav, emotion_code: E
# Features shape for 11a02Ec.wav: (1, 62)
# Processing 11a02Fb.wav, emotion_code: F
# Features shape for 11a02Fb.wav: (1, 62)
# Processing 11a02Ld.wav, emotion_code: L
# Features shape for 11a02Ld.wav: (1, 62)
# Processing 11a02Nc.wav, emotion_code: N
# Features shape for 11a02Nc.wav: (1, 62)
# Processing 11a02Tc.wav, emotion_code: T
# Features shape for 11a02Tc.wav: (1, 62)
# Processing 11a02Wc.wav, emotion_code: W
# Features shape for 11a02Wc.wav: (1, 62)
# Processing 11a04Ac.wav, emotion_code: A
# Features shape for 11a04Ac.wav: (1, 62)
# Processing 11a04Fd.wav, emotion_code: F
# Features shape for 11a04Fd.wav: (1, 62)
# Processing 11a04Nd.wav, emotion_code: N
# Features shape for 11a04Nd.wav: (1, 62)
# Processing 11a04Wc.wav, emotion_code: W
# Features shape for 11a04Wc.wav: (1, 62)
# Processing 11a05Ad.wav, emotion_code: A
# Features shape for 11a05Ad.wav: (1, 62)
# Processing 11a05Fb.wav, emotion_code: F
# Features shape for 11a05Fb.wav: (1, 62)
# Processing 11a05Fc.wav, emotion_code: F
# Features shape for 11a05Fc.wav: (1, 62)
# Processing 11a05Lc.wav, emotion_code: L
# Features shape for 11a05Lc.wav: (1, 62)
# Processing 11a05Na.wav, emotion_code: N
# Features shape for 11a05Na.wav: (1, 62)
# Processing 11a05Td.wav, emotion_code: T
# Features shape for 11a05Td.wav: (1, 62)
# Processing 11a05Wd.wav, emotion_code: W
# Features shape for 11a05Wd.wav: (1, 62)
# Processing 11a07Ac.wav, emotion_code: A
# Features shape for 11a07Ac.wav: (1, 62)
# Processing 11a07Ld.wav, emotion_code: L
# Features shape for 11a07Ld.wav: (1, 62)
# Processing 11a07Ta.wav, emotion_code: T
# Features shape for 11a07Ta.wav: (1, 62)
# Processing 11a07Wc.wav, emotion_code: W
# Features shape for 11a07Wc.wav: (1, 62)
# Processing 11b01Ab.wav, emotion_code: A
# Features shape for 11b01Ab.wav: (1, 62)
# Processing 11b01Eb.wav, emotion_code: E
# Features shape for 11b01Eb.wav: (1, 62)
# Processing 11b01Fc.wav, emotion_code: F
# Features shape for 11b01Fc.wav: (1, 62)
# Processing 11b01Lb.wav, emotion_code: L
# Features shape for 11b01Lb.wav: (1, 62)
# Processing 11b01Nc.wav, emotion_code: N
# Features shape for 11b01Nc.wav: (1, 62)
# Processing 11b01Wd.wav, emotion_code: W
# Features shape for 11b01Wd.wav: (1, 62)
# Processing 11b02Ab.wav, emotion_code: A
# Features shape for 11b02Ab.wav: (1, 62)
# Processing 11b02Fd.wav, emotion_code: F
# Features shape for 11b02Fd.wav: (1, 62)
# Processing 11b02Na.wav, emotion_code: N
# Features shape for 11b02Na.wav: (1, 62)
# Processing 11b02Td.wav, emotion_code: T
# Features shape for 11b02Td.wav: (1, 62)
# Processing 11b02Wb.wav, emotion_code: W
# Features shape for 11b02Wb.wav: (1, 62)
# Processing 11b03Fc.wav, emotion_code: F
# Features shape for 11b03Fc.wav: (1, 62)
# Processing 11b03Lc.wav, emotion_code: L
# Features shape for 11b03Lc.wav: (1, 62)
# Processing 11b03Nb.wav, emotion_code: N
# Features shape for 11b03Nb.wav: (1, 62)
# Processing 11b03Td.wav, emotion_code: T
# Features shape for 11b03Td.wav: (1, 62)
# Processing 11b03Wa.wav, emotion_code: W
# Features shape for 11b03Wa.wav: (1, 62)
# Processing 11b03Wb.wav, emotion_code: W
# Features shape for 11b03Wb.wav: (1, 62)
# Processing 11b09Ad.wav, emotion_code: A
# Features shape for 11b09Ad.wav: (1, 62)
# Processing 11b09Fd.wav, emotion_code: F
# Features shape for 11b09Fd.wav: (1, 62)
# Processing 11b09Ld.wav, emotion_code: L
# Features shape for 11b09Ld.wav: (1, 62)
# Processing 11b09Na.wav, emotion_code: N
# Features shape for 11b09Na.wav: (1, 62)
# Processing 11b09Td.wav, emotion_code: T
# Features shape for 11b09Td.wav: (1, 62)
# Processing 11b09Wa.wav, emotion_code: W
# Features shape for 11b09Wa.wav: (1, 62)
# Processing 11b10Ad.wav, emotion_code: A
# Features shape for 11b10Ad.wav: (1, 62)
# Processing 11b10Ae.wav, emotion_code: A
# Features shape for 11b10Ae.wav: (1, 62)
# Processing 11b10Ld.wav, emotion_code: L
# Features shape for 11b10Ld.wav: (1, 62)
# Processing 11b10Nc.wav, emotion_code: N
# Features shape for 11b10Nc.wav: (1, 62)
# Processing 11b10Td.wav, emotion_code: T
# Features shape for 11b10Td.wav: (1, 62)
# Processing 11b10Wa.wav, emotion_code: W
# Features shape for 11b10Wa.wav: (1, 62)
# Processing 12a01Fb.wav, emotion_code: F
# Features shape for 12a01Fb.wav: (1, 62)
# Processing 12a01Lb.wav, emotion_code: L
# Features shape for 12a01Lb.wav: (1, 62)
# Processing 12a01Nb.wav, emotion_code: N
# Features shape for 12a01Nb.wav: (1, 62)
# Processing 12a01Wc.wav, emotion_code: W
# Features shape for 12a01Wc.wav: (1, 62)
# Processing 12a02Ac.wav, emotion_code: A
# Features shape for 12a02Ac.wav: (1, 62)
# Processing 12a02Ec.wav, emotion_code: E
# Features shape for 12a02Ec.wav: (1, 62)
# Processing 12a02Nb.wav, emotion_code: N
# Features shape for 12a02Nb.wav: (1, 62)
# Processing 12a02Wa.wav, emotion_code: W
# Features shape for 12a02Wa.wav: (1, 62)
# Processing 12a02Wc.wav, emotion_code: W
# Features shape for 12a02Wc.wav: (1, 62)
# Processing 12a04Wc.wav, emotion_code: W
# Features shape for 12a04Wc.wav: (1, 62)
# Processing 12a05Ab.wav, emotion_code: A
# Features shape for 12a05Ab.wav: (1, 62)
# Processing 12a05Lb.wav, emotion_code: L
# Features shape for 12a05Lb.wav: (1, 62)
# Processing 12a05Nd.wav, emotion_code: N
# Features shape for 12a05Nd.wav: (1, 62)
# Processing 12a05Ta.wav, emotion_code: T
# Features shape for 12a05Ta.wav: (1, 62)
# Processing 12a05Wb.wav, emotion_code: W
# Features shape for 12a05Wb.wav: (1, 62)
# Processing 12a07Ac.wav, emotion_code: A
# Features shape for 12a07Ac.wav: (1, 62)
# Processing 12a07La.wav, emotion_code: L
# Features shape for 12a07La.wav: (1, 62)
# Processing 12a07Wa.wav, emotion_code: W
# Features shape for 12a07Wa.wav: (1, 62)
# Processing 12b01Ta.wav, emotion_code: T
# Features shape for 12b01Ta.wav: (1, 62)
# Processing 12b01Wa.wav, emotion_code: W
# Features shape for 12b01Wa.wav: (1, 62)
# Processing 12b02Ad.wav, emotion_code: A
# Features shape for 12b02Ad.wav: (1, 62)
# Processing 12b02Ea.wav, emotion_code: E
# Features shape for 12b02Ea.wav: (1, 62)
# Processing 12b02Fb.wav, emotion_code: F
# Features shape for 12b02Fb.wav: (1, 62)
# Processing 12b02Na.wav, emotion_code: N
# Features shape for 12b02Na.wav: (1, 62)
# Processing 12b02Wa.wav, emotion_code: W
# Features shape for 12b02Wa.wav: (1, 62)
# Processing 12b02Wb.wav, emotion_code: W
# Features shape for 12b02Wb.wav: (1, 62)
# Processing 12b02Wd.wav, emotion_code: W
# Features shape for 12b02Wd.wav: (1, 62)
# Processing 12b03La.wav, emotion_code: L
# Features shape for 12b03La.wav: (1, 62)
# Processing 12b03Ta.wav, emotion_code: T
# Features shape for 12b03Ta.wav: (1, 62)
# Processing 12b09Ac.wav, emotion_code: A
# Features shape for 12b09Ac.wav: (1, 62)
# Processing 12b09Td.wav, emotion_code: T
# Features shape for 12b09Td.wav: (1, 62)
# Processing 12b09Wc.wav, emotion_code: W
# Features shape for 12b09Wc.wav: (1, 62)
# Processing 12b10Ac.wav, emotion_code: A
# Features shape for 12b10Ac.wav: (1, 62)
# Processing 12b10Ld.wav, emotion_code: L
# Features shape for 12b10Ld.wav: (1, 62)
# Processing 12b10Wa.wav, emotion_code: W
# Features shape for 12b10Wa.wav: (1, 62)
# Processing 13a01Ac.wav, emotion_code: A
# Features shape for 13a01Ac.wav: (1, 62)
# Processing 13a01Ea.wav, emotion_code: E
# Features shape for 13a01Ea.wav: (1, 62)
# Processing 13a01Ec.wav, emotion_code: E
# Features shape for 13a01Ec.wav: (1, 62)
# Processing 13a01Fd.wav, emotion_code: F
# Features shape for 13a01Fd.wav: (1, 62)
# Processing 13a01Lb.wav, emotion_code: L
# Features shape for 13a01Lb.wav: (1, 62)
# Processing 13a01Nb.wav, emotion_code: N
# Features shape for 13a01Nb.wav: (1, 62)
# Processing 13a01Wb.wav, emotion_code: W
# Features shape for 13a01Wb.wav: (1, 62)
# Processing 13a02Ad.wav, emotion_code: A
# Features shape for 13a02Ad.wav: (1, 62)
# Processing 13a02Ec.wav, emotion_code: E
# Features shape for 13a02Ec.wav: (1, 62)
# Processing 13a02Fa.wav, emotion_code: F
# Features shape for 13a02Fa.wav: (1, 62)
# Processing 13a02Lc.wav, emotion_code: L
# Features shape for 13a02Lc.wav: (1, 62)
# Processing 13a02Nc.wav, emotion_code: N
# Features shape for 13a02Nc.wav: (1, 62)
# Processing 13a02Ta.wav, emotion_code: T
# Features shape for 13a02Ta.wav: (1, 62)
# Processing 13a02Wa.wav, emotion_code: W
# Features shape for 13a02Wa.wav: (1, 62)
# Processing 13a04Ac.wav, emotion_code: A
# Features shape for 13a04Ac.wav: (1, 62)
# Processing 13a04Fc.wav, emotion_code: F
# Features shape for 13a04Fc.wav: (1, 62)
# Processing 13a04Lb.wav, emotion_code: L
# Features shape for 13a04Lb.wav: (1, 62)
# Processing 13a04Ta.wav, emotion_code: T
# Features shape for 13a04Ta.wav: (1, 62)
# Processing 13a04Wc.wav, emotion_code: W
# Features shape for 13a04Wc.wav: (1, 62)
# Processing 13a05Aa.wav, emotion_code: A
# Features shape for 13a05Aa.wav: (1, 62)
# Processing 13a05Ea.wav, emotion_code: E
# Features shape for 13a05Ea.wav: (1, 62)
# Processing 13a05Lc.wav, emotion_code: L
# Features shape for 13a05Lc.wav: (1, 62)
# Processing 13a05Nb.wav, emotion_code: N
# Features shape for 13a05Nb.wav: (1, 62)
# Processing 13a05Tc.wav, emotion_code: T
# Features shape for 13a05Tc.wav: (1, 62)
# Processing 13a05Wa.wav, emotion_code: W
# Features shape for 13a05Wa.wav: (1, 62)
# Processing 13a05Wc.wav, emotion_code: W
# Features shape for 13a05Wc.wav: (1, 62)
# Processing 13a07Fd.wav, emotion_code: F
# Features shape for 13a07Fd.wav: (1, 62)
# Processing 13a07Lb.wav, emotion_code: L
# Features shape for 13a07Lb.wav: (1, 62)
# Processing 13a07Na.wav, emotion_code: N
# Features shape for 13a07Na.wav: (1, 62)
# Processing 13a07Tc.wav, emotion_code: T
# Features shape for 13a07Tc.wav: (1, 62)
# Processing 13a07Wb.wav, emotion_code: W
# Features shape for 13a07Wb.wav: (1, 62)
# Processing 13b01Ab.wav, emotion_code: A
# Features shape for 13b01Ab.wav: (1, 62)
# Processing 13b01Ec.wav, emotion_code: E
# Features shape for 13b01Ec.wav: (1, 62)
# Processing 13b01Fc.wav, emotion_code: F
# Features shape for 13b01Fc.wav: (1, 62)
# Processing 13b01Ld.wav, emotion_code: L
# Features shape for 13b01Ld.wav: (1, 62)
# Processing 13b01Nc.wav, emotion_code: N
# Features shape for 13b01Nc.wav: (1, 62)
# Processing 13b01Wa.wav, emotion_code: W
# Features shape for 13b01Wa.wav: (1, 62)
# Processing 13b02Fb.wav, emotion_code: F
# Features shape for 13b02Fb.wav: (1, 62)
# Processing 13b02Lc.wav, emotion_code: L
# Features shape for 13b02Lc.wav: (1, 62)
# Processing 13b02Nb.wav, emotion_code: N
# Features shape for 13b02Nb.wav: (1, 62)
# Processing 13b02Wa.wav, emotion_code: W
# Features shape for 13b02Wa.wav: (1, 62)
# Processing 13b03Ac.wav, emotion_code: A
# Features shape for 13b03Ac.wav: (1, 62)
# Processing 13b03Ed.wav, emotion_code: E
# Features shape for 13b03Ed.wav: (1, 62)
# Processing 13b03Fd.wav, emotion_code: F
# Features shape for 13b03Fd.wav: (1, 62)
# Processing 13b03Lb.wav, emotion_code: L
# Features shape for 13b03Lb.wav: (1, 62)
# Processing 13b03Na.wav, emotion_code: N
# Features shape for 13b03Na.wav: (1, 62)
# Processing 13b03Td.wav, emotion_code: T
# Features shape for 13b03Td.wav: (1, 62)
# Processing 13b03Wc.wav, emotion_code: W
# Features shape for 13b03Wc.wav: (1, 62)
# Processing 13b09Ab.wav, emotion_code: A
# Features shape for 13b09Ab.wav: (1, 62)
# Processing 13b09Ec.wav, emotion_code: E
# Features shape for 13b09Ec.wav: (1, 62)
# Processing 13b09Fb.wav, emotion_code: F
# Features shape for 13b09Fb.wav: (1, 62)
# Processing 13b09Fc.wav, emotion_code: F
# Features shape for 13b09Fc.wav: (1, 62)
# Processing 13b09La.wav, emotion_code: L
# Features shape for 13b09La.wav: (1, 62)
# Processing 13b09Na.wav, emotion_code: N
# Features shape for 13b09Na.wav: (1, 62)
# Processing 13b09Wa.wav, emotion_code: W
# Features shape for 13b09Wa.wav: (1, 62)
# Processing 13b10Ec.wav, emotion_code: E
# Features shape for 13b10Ec.wav: (1, 62)
# Processing 13b10Fa.wav, emotion_code: F
# Features shape for 13b10Fa.wav: (1, 62)
# Processing 13b10La.wav, emotion_code: L
# Features shape for 13b10La.wav: (1, 62)
# Processing 13b10Nc.wav, emotion_code: N
# Features shape for 13b10Nc.wav: (1, 62)
# Processing 13b10Wa.wav, emotion_code: W
# Features shape for 13b10Wa.wav: (1, 62)
# Processing 13b10Wc.wav, emotion_code: W
# Features shape for 13b10Wc.wav: (1, 62)
# Processing 14a01Aa.wav, emotion_code: A
# Features shape for 14a01Aa.wav: (1, 62)
# Processing 14a01Ac.wav, emotion_code: A
# Features shape for 14a01Ac.wav: (1, 62)
# Processing 14a01Ea.wav, emotion_code: E
# Features shape for 14a01Ea.wav: (1, 62)
# Processing 14a01Na.wav, emotion_code: N
# Features shape for 14a01Na.wav: (1, 62)
# Processing 14a01Wa.wav, emotion_code: W
# Features shape for 14a01Wa.wav: (1, 62)
# Processing 14a01Wc.wav, emotion_code: W
# Features shape for 14a01Wc.wav: (1, 62)
# Processing 14a02Ab.wav, emotion_code: A
# Features shape for 14a02Ab.wav: (1, 62)
# Processing 14a02Ea.wav, emotion_code: E
# Features shape for 14a02Ea.wav: (1, 62)
# Processing 14a02Fd.wav, emotion_code: F
# Features shape for 14a02Fd.wav: (1, 62)
# Processing 14a02La.wav, emotion_code: L
# Features shape for 14a02La.wav: (1, 62)
# Processing 14a02Nc.wav, emotion_code: N
# Features shape for 14a02Nc.wav: (1, 62)
# Processing 14a02Tb.wav, emotion_code: T
# Features shape for 14a02Tb.wav: (1, 62)
# Processing 14a02Wa.wav, emotion_code: W
# Features shape for 14a02Wa.wav: (1, 62)
# Processing 14a02Wc.wav, emotion_code: W
# Features shape for 14a02Wc.wav: (1, 62)
# Processing 14a04Aa.wav, emotion_code: A
# Features shape for 14a04Aa.wav: (1, 62)
# Processing 14a04Ed.wav, emotion_code: E
# Features shape for 14a04Ed.wav: (1, 62)
# Processing 14a04Lb.wav, emotion_code: L
# Features shape for 14a04Lb.wav: (1, 62)
# Processing 14a04Tb.wav, emotion_code: T
# Features shape for 14a04Tb.wav: (1, 62)
# Processing 14a04Tc.wav, emotion_code: T
# Features shape for 14a04Tc.wav: (1, 62)
# Processing 14a04Wb.wav, emotion_code: W
# Features shape for 14a04Wb.wav: (1, 62)
# Processing 14a04Wc.wav, emotion_code: W
# Features shape for 14a04Wc.wav: (1, 62)
# Processing 14a05Aa.wav, emotion_code: A
# Features shape for 14a05Aa.wav: (1, 62)
# Processing 14a05Ac.wav, emotion_code: A
# Features shape for 14a05Ac.wav: (1, 62)
# Processing 14a05Fa.wav, emotion_code: F
# Features shape for 14a05Fa.wav: (1, 62)
# Processing 14a05Fb.wav, emotion_code: F
# Features shape for 14a05Fb.wav: (1, 62)
# Processing 14a05Lb.wav, emotion_code: L
# Features shape for 14a05Lb.wav: (1, 62)
# Processing 14a05Na.wav, emotion_code: N
# Features shape for 14a05Na.wav: (1, 62)
# Processing 14a05Ta.wav, emotion_code: T
# Features shape for 14a05Ta.wav: (1, 62)
# Processing 14a05Tc.wav, emotion_code: T
# Features shape for 14a05Tc.wav: (1, 62)
# Processing 14a05Wa.wav, emotion_code: W
# Features shape for 14a05Wa.wav: (1, 62)
# Processing 14a05Wb.wav, emotion_code: W
# Features shape for 14a05Wb.wav: (1, 62)
# Processing 14a07Aa.wav, emotion_code: A
# Features shape for 14a07Aa.wav: (1, 62)
# Processing 14a07Eb.wav, emotion_code: E
# Features shape for 14a07Eb.wav: (1, 62)
# Processing 14a07Fd.wav, emotion_code: F
# Features shape for 14a07Fd.wav: (1, 62)
# Processing 14a07Lc.wav, emotion_code: L
# Features shape for 14a07Lc.wav: (1, 62)
# Processing 14a07Ld.wav, emotion_code: L
# Features shape for 14a07Ld.wav: (1, 62)
# Processing 14a07Na.wav, emotion_code: N
# Features shape for 14a07Na.wav: (1, 62)
# Processing 14a07Tc.wav, emotion_code: T
# Features shape for 14a07Tc.wav: (1, 62)
# Processing 14a07Wc.wav, emotion_code: W
# Features shape for 14a07Wc.wav: (1, 62)
# Processing 14b01Ac.wav, emotion_code: A
# Features shape for 14b01Ac.wav: (1, 62)
# Processing 14b01Eb.wav, emotion_code: E
# Features shape for 14b01Eb.wav: (1, 62)
# Processing 14b01Fa.wav, emotion_code: F
# Features shape for 14b01Fa.wav: (1, 62)
# Processing 14b01Fc.wav, emotion_code: F
# Features shape for 14b01Fc.wav: (1, 62)
# Processing 14b01Na.wav, emotion_code: N
# Features shape for 14b01Na.wav: (1, 62)
# Processing 14b01Wc.wav, emotion_code: W
# Features shape for 14b01Wc.wav: (1, 62)
# Processing 14b02Aa.wav, emotion_code: A
# Features shape for 14b02Aa.wav: (1, 62)
# Processing 14b02Fb.wav, emotion_code: F
# Features shape for 14b02Fb.wav: (1, 62)
# Processing 14b02Na.wav, emotion_code: N
# Features shape for 14b02Na.wav: (1, 62)
# Processing 14b02Tc.wav, emotion_code: T
# Features shape for 14b02Tc.wav: (1, 62)
# Processing 14b02Wb.wav, emotion_code: W
# Features shape for 14b02Wb.wav: (1, 62)
# Processing 14b02Wd.wav, emotion_code: W
# Features shape for 14b02Wd.wav: (1, 62)
# Processing 14b03Ad.wav, emotion_code: A
# Features shape for 14b03Ad.wav: (1, 62)
# Processing 14b03Ed.wav, emotion_code: E
# Features shape for 14b03Ed.wav: (1, 62)
# Processing 14b03Lb.wav, emotion_code: L
# Features shape for 14b03Lb.wav: (1, 62)
# Processing 14b03Ta.wav, emotion_code: T
# Features shape for 14b03Ta.wav: (1, 62)
# Processing 14b03Wb.wav, emotion_code: W
# Features shape for 14b03Wb.wav: (1, 62)
# Processing 14b09Ac.wav, emotion_code: A
# Features shape for 14b09Ac.wav: (1, 62)
# Processing 14b09Ea.wav, emotion_code: E
# Features shape for 14b09Ea.wav: (1, 62)
# Processing 14b09Fc.wav, emotion_code: F
# Features shape for 14b09Fc.wav: (1, 62)
# Processing 14b09Lb.wav, emotion_code: L
# Features shape for 14b09Lb.wav: (1, 62)
# Processing 14b09Td.wav, emotion_code: T
# Features shape for 14b09Td.wav: (1, 62)
# Processing 14b09Wa.wav, emotion_code: W
# Features shape for 14b09Wa.wav: (1, 62)
# Processing 14b09Wc.wav, emotion_code: W
# Features shape for 14b09Wc.wav: (1, 62)
# Processing 14b10Ad.wav, emotion_code: A
# Features shape for 14b10Ad.wav: (1, 62)
# Processing 14b10Eb.wav, emotion_code: E
# Features shape for 14b10Eb.wav: (1, 62)
# Processing 14b10Lb.wav, emotion_code: L
# Features shape for 14b10Lb.wav: (1, 62)
# Processing 14b10Nb.wav, emotion_code: N
# Features shape for 14b10Nb.wav: (1, 62)
# Processing 14b10Tc.wav, emotion_code: T
# Features shape for 14b10Tc.wav: (1, 62)
# Processing 14b10Wc.wav, emotion_code: W
# Features shape for 14b10Wc.wav: (1, 62)
# Processing 15a01Ea.wav, emotion_code: E
# Features shape for 15a01Ea.wav: (1, 62)
# Processing 15a01Fb.wav, emotion_code: F
# Features shape for 15a01Fb.wav: (1, 62)
# Processing 15a01La.wav, emotion_code: L
# Features shape for 15a01La.wav: (1, 62)
# Processing 15a01Nb.wav, emotion_code: N
# Features shape for 15a01Nb.wav: (1, 62)
# Processing 15a01Wa.wav, emotion_code: W
# Features shape for 15a01Wa.wav: (1, 62)
# Processing 15a02Ac.wav, emotion_code: A
# Features shape for 15a02Ac.wav: (1, 62)
# Processing 15a02Ea.wav, emotion_code: E
# Features shape for 15a02Ea.wav: (1, 62)
# Processing 15a02La.wav, emotion_code: L
# Features shape for 15a02La.wav: (1, 62)
# Processing 15a02Na.wav, emotion_code: N
# Features shape for 15a02Na.wav: (1, 62)
# Processing 15a02Ta.wav, emotion_code: T
# Features shape for 15a02Ta.wav: (1, 62)
# Processing 15a02Wb.wav, emotion_code: W
# Features shape for 15a02Wb.wav: (1, 62)
# Processing 15a02Wd.wav, emotion_code: W
# Features shape for 15a02Wd.wav: (1, 62)
# Processing 15a04Ab.wav, emotion_code: A
# Features shape for 15a04Ab.wav: (1, 62)
# Processing 15a04Ac.wav, emotion_code: A
# Features shape for 15a04Ac.wav: (1, 62)
# Processing 15a04Fd.wav, emotion_code: F
# Features shape for 15a04Fd.wav: (1, 62)
# Processing 15a04Nc.wav, emotion_code: N
# Features shape for 15a04Nc.wav: (1, 62)
# Processing 15a04Wa.wav, emotion_code: W
# Features shape for 15a04Wa.wav: (1, 62)
# Processing 15a04Wb.wav, emotion_code: W
# Features shape for 15a04Wb.wav: (1, 62)
# Processing 15a05Eb.wav, emotion_code: E
# Features shape for 15a05Eb.wav: (1, 62)
# Processing 15a05Fb.wav, emotion_code: F
# Features shape for 15a05Fb.wav: (1, 62)
# Processing 15a05Lb.wav, emotion_code: L
# Features shape for 15a05Lb.wav: (1, 62)
# Processing 15a05Na.wav, emotion_code: N
# Features shape for 15a05Na.wav: (1, 62)
# Processing 15a05Wa.wav, emotion_code: W
# Features shape for 15a05Wa.wav: (1, 62)
# Processing 15a07Ac.wav, emotion_code: A
# Features shape for 15a07Ac.wav: (1, 62)
# Processing 15a07Eb.wav, emotion_code: E
# Features shape for 15a07Eb.wav: (1, 62)
# Processing 15a07Fa.wav, emotion_code: F
# Features shape for 15a07Fa.wav: (1, 62)
# Processing 15a07Fb.wav, emotion_code: F
# Features shape for 15a07Fb.wav: (1, 62)
# Processing 15a07Ld.wav, emotion_code: L
# Features shape for 15a07Ld.wav: (1, 62)
# Processing 15a07Nc.wav, emotion_code: N
# Features shape for 15a07Nc.wav: (1, 62)
# Processing 15b01Ec.wav, emotion_code: E
# Features shape for 15b01Ec.wav: (1, 62)
# Processing 15b01Lb.wav, emotion_code: L
# Features shape for 15b01Lb.wav: (1, 62)
# Processing 15b01Na.wav, emotion_code: N
# Features shape for 15b01Na.wav: (1, 62)
# Processing 15b01Wc.wav, emotion_code: W
# Features shape for 15b01Wc.wav: (1, 62)
# Processing 15b02Aa.wav, emotion_code: A
# Features shape for 15b02Aa.wav: (1, 62)
# Processing 15b02Lb.wav, emotion_code: L
# Features shape for 15b02Lb.wav: (1, 62)
# Processing 15b02Nd.wav, emotion_code: N
# Features shape for 15b02Nd.wav: (1, 62)
# Processing 15b02Tc.wav, emotion_code: T
# Features shape for 15b02Tc.wav: (1, 62)
# Processing 15b02Wa.wav, emotion_code: W
# Features shape for 15b02Wa.wav: (1, 62)
# Processing 15b02Wc.wav, emotion_code: W
# Features shape for 15b02Wc.wav: (1, 62)
# Processing 15b03Aa.wav, emotion_code: A
# Features shape for 15b03Aa.wav: (1, 62)
# Processing 15b03Lc.wav, emotion_code: L
# Features shape for 15b03Lc.wav: (1, 62)
# Processing 15b03Nb.wav, emotion_code: N
# Features shape for 15b03Nb.wav: (1, 62)
# Processing 15b03Tc.wav, emotion_code: T
# Features shape for 15b03Tc.wav: (1, 62)
# Processing 15b03Wa.wav, emotion_code: W
# Features shape for 15b03Wa.wav: (1, 62)
# Processing 15b03Wb.wav, emotion_code: W
# Features shape for 15b03Wb.wav: (1, 62)
# Processing 15b09Ac.wav, emotion_code: A
# Features shape for 15b09Ac.wav: (1, 62)
# Processing 15b09Fa.wav, emotion_code: F
# Features shape for 15b09Fa.wav: (1, 62)
# Processing 15b09La.wav, emotion_code: L
# Features shape for 15b09La.wav: (1, 62)
# Processing 15b09Nb.wav, emotion_code: N
# Features shape for 15b09Nb.wav: (1, 62)
# Processing 15b09Ta.wav, emotion_code: T
# Features shape for 15b09Ta.wav: (1, 62)
# Processing 15b09Wb.wav, emotion_code: W
# Features shape for 15b09Wb.wav: (1, 62)
# Processing 15b10Ac.wav, emotion_code: A
# Features shape for 15b10Ac.wav: (1, 62)
# Processing 15b10Lc.wav, emotion_code: L
# Features shape for 15b10Lc.wav: (1, 62)
# Processing 15b10Nb.wav, emotion_code: N
# Features shape for 15b10Nb.wav: (1, 62)
# Processing 15b10Nc.wav, emotion_code: N
# Features shape for 15b10Nc.wav: (1, 62)
# Processing 15b10Wa.wav, emotion_code: W
# Features shape for 15b10Wa.wav: (1, 62)
# Processing 16a01Ec.wav, emotion_code: E
# Features shape for 16a01Ec.wav: (1, 62)
# Processing 16a01Fc.wav, emotion_code: F
# Features shape for 16a01Fc.wav: (1, 62)
# Processing 16a01Lb.wav, emotion_code: L
# Features shape for 16a01Lb.wav: (1, 62)
# Processing 16a01Nc.wav, emotion_code: N
# Features shape for 16a01Nc.wav: (1, 62)
# Processing 16a01Tb.wav, emotion_code: T
# Features shape for 16a01Tb.wav: (1, 62)
# Processing 16a01Wb.wav, emotion_code: W
# Features shape for 16a01Wb.wav: (1, 62)
# Processing 16a02Ea.wav, emotion_code: E
# Features shape for 16a02Ea.wav: (1, 62)
# Processing 16a02Ec.wav, emotion_code: E
# Features shape for 16a02Ec.wav: (1, 62)
# Processing 16a02Lb.wav, emotion_code: L
# Features shape for 16a02Lb.wav: (1, 62)
# Processing 16a02Nb.wav, emotion_code: N
# Features shape for 16a02Nb.wav: (1, 62)
# Processing 16a02Tc.wav, emotion_code: T
# Features shape for 16a02Tc.wav: (1, 62)
# Processing 16a02Wb.wav, emotion_code: W
# Features shape for 16a02Wb.wav: (1, 62)
# Processing 16a04Ab.wav, emotion_code: A
# Features shape for 16a04Ab.wav: (1, 62)
# Processing 16a04Ea.wav, emotion_code: E
# Features shape for 16a04Ea.wav: (1, 62)
# Processing 16a04Fa.wav, emotion_code: F
# Features shape for 16a04Fa.wav: (1, 62)
# Processing 16a04La.wav, emotion_code: L
# Features shape for 16a04La.wav: (1, 62)
# Processing 16a04Lc.wav, emotion_code: L
# Features shape for 16a04Lc.wav: (1, 62)
# Processing 16a04Nc.wav, emotion_code: N
# Features shape for 16a04Nc.wav: (1, 62)
# Processing 16a04Tc.wav, emotion_code: T
# Features shape for 16a04Tc.wav: (1, 62)
# Processing 16a04Wb.wav, emotion_code: W
# Features shape for 16a04Wb.wav: (1, 62)
# Processing 16a04Wc.wav, emotion_code: W
# Features shape for 16a04Wc.wav: (1, 62)
# Processing 16a05Ab.wav, emotion_code: A
# Features shape for 16a05Ab.wav: (1, 62)
# Processing 16a05Ea.wav, emotion_code: E
# Features shape for 16a05Ea.wav: (1, 62)
# Processing 16a05Fc.wav, emotion_code: F
# Features shape for 16a05Fc.wav: (1, 62)
# Processing 16a05La.wav, emotion_code: L
# Features shape for 16a05La.wav: (1, 62)
# Processing 16a05Tb.wav, emotion_code: T
# Features shape for 16a05Tb.wav: (1, 62)
# Processing 16a05Wb.wav, emotion_code: W
# Features shape for 16a05Wb.wav: (1, 62)
# Processing 16a05Wc.wav, emotion_code: W
# Features shape for 16a05Wc.wav: (1, 62)
# Processing 16a07Ea.wav, emotion_code: E
# Features shape for 16a07Ea.wav: (1, 62)
# Processing 16a07Fa.wav, emotion_code: F
# Features shape for 16a07Fa.wav: (1, 62)
# Processing 16a07Fb.wav, emotion_code: F
# Features shape for 16a07Fb.wav: (1, 62)
# Processing 16a07La.wav, emotion_code: L
# Features shape for 16a07La.wav: (1, 62)
# Processing 16a07Lb.wav, emotion_code: L
# Features shape for 16a07Lb.wav: (1, 62)
# Processing 16a07Nb.wav, emotion_code: N
# Features shape for 16a07Nb.wav: (1, 62)
# Processing 16a07Td.wav, emotion_code: T
# Features shape for 16a07Td.wav: (1, 62)
# Processing 16a07Wa.wav, emotion_code: W
# Features shape for 16a07Wa.wav: (1, 62)
# Processing 16b01Aa.wav, emotion_code: A
# Features shape for 16b01Aa.wav: (1, 62)
# Processing 16b01Eb.wav, emotion_code: E
# Features shape for 16b01Eb.wav: (1, 62)
# Processing 16b01Fa.wav, emotion_code: F
# Features shape for 16b01Fa.wav: (1, 62)
# Processing 16b01La.wav, emotion_code: L
# Features shape for 16b01La.wav: (1, 62)
# Processing 16b01Lc.wav, emotion_code: L
# Features shape for 16b01Lc.wav: (1, 62)
# Processing 16b01Tb.wav, emotion_code: T
# Features shape for 16b01Tb.wav: (1, 62)
# Processing 16b01Wa.wav, emotion_code: W
# Features shape for 16b01Wa.wav: (1, 62)
# Processing 16b01Wb.wav, emotion_code: W
# Features shape for 16b01Wb.wav: (1, 62)
# Processing 16b02Aa.wav, emotion_code: A
# Features shape for 16b02Aa.wav: (1, 62)
# Processing 16b02Eb.wav, emotion_code: E
# Features shape for 16b02Eb.wav: (1, 62)
# Processing 16b02Fd.wav, emotion_code: F
# Features shape for 16b02Fd.wav: (1, 62)
# Processing 16b02Lb.wav, emotion_code: L
# Features shape for 16b02Lb.wav: (1, 62)
# Processing 16b02Wb.wav, emotion_code: W
# Features shape for 16b02Wb.wav: (1, 62)
# Processing 16b03Ad.wav, emotion_code: A
# Features shape for 16b03Ad.wav: (1, 62)
# Processing 16b03Ea.wav, emotion_code: E
# Features shape for 16b03Ea.wav: (1, 62)
# Processing 16b03Fa.wav, emotion_code: F
# Features shape for 16b03Fa.wav: (1, 62)
# Processing 16b03Fd.wav, emotion_code: F
# Features shape for 16b03Fd.wav: (1, 62)
# Processing 16b03La.wav, emotion_code: L
# Features shape for 16b03La.wav: (1, 62)
# Processing 16b03Nb.wav, emotion_code: N
# Features shape for 16b03Nb.wav: (1, 62)
# Processing 16b03Ta.wav, emotion_code: T
# Features shape for 16b03Ta.wav: (1, 62)
# Processing 16b03Wb.wav, emotion_code: W
# Features shape for 16b03Wb.wav: (1, 62)
# Processing 16b09Ab.wav, emotion_code: A
# Features shape for 16b09Ab.wav: (1, 62)
# Processing 16b09Eb.wav, emotion_code: E
# Features shape for 16b09Eb.wav: (1, 62)
# Processing 16b09Fb.wav, emotion_code: F
# Features shape for 16b09Fb.wav: (1, 62)
# Processing 16b09La.wav, emotion_code: L
# Features shape for 16b09La.wav: (1, 62)
# Processing 16b09Lb.wav, emotion_code: L
# Features shape for 16b09Lb.wav: (1, 62)
# Processing 16b09Wb.wav, emotion_code: W
# Features shape for 16b09Wb.wav: (1, 62)
# Processing 16b10Aa.wav, emotion_code: A
# Features shape for 16b10Aa.wav: (1, 62)
# Processing 16b10Eb.wav, emotion_code: E
# Features shape for 16b10Eb.wav: (1, 62)
# Processing 16b10Fb.wav, emotion_code: F
# Features shape for 16b10Fb.wav: (1, 62)
# Processing 16b10Lb.wav, emotion_code: L
# Features shape for 16b10Lb.wav: (1, 62)
# Processing 16b10Tb.wav, emotion_code: T
# Features shape for 16b10Tb.wav: (1, 62)
# Processing 16b10Td.wav, emotion_code: T
# Features shape for 16b10Td.wav: (1, 62)
# Processing 16b10Wa.wav, emotion_code: W
# Features shape for 16b10Wa.wav: (1, 62)
# Processing 16b10Wb.wav, emotion_code: W
# Features shape for 16b10Wb.wav: (1, 62)
#               precision    recall  f1-score   support
#
#        Anger       0.47      0.57      0.52        14
#      Boredom       0.88      0.58      0.70        12
#      Disgust       0.45      0.56      0.50        18
# Anxiety/Fear       0.86      0.95      0.90        20
#    Happiness       0.67      0.50      0.57        16
#      Sadness       0.90      1.00      0.95         9
#      Neutral       0.75      0.67      0.71        18
#
#     accuracy                           0.68       107
#    macro avg       0.71      0.69      0.69       107
# weighted avg       0.70      0.68      0.68       107

# %% [markdown]
# ## open smile with a very simple NN

# %% [markdown]
# ### feature extraction

# %%
import os
import numpy as np
import opensmile
import pickle
from sklearn.preprocessing import StandardScaler


# Emotion labels
emotion_labels = {
    'W': 'Anger',
    'L': 'Boredom',
    'E': 'Disgust',
    'A': 'Anxiety/Fear',
    'F': 'Happiness',
    'T': 'Sadness',
    'N': 'Neutral'
}
label_to_idx = {label: idx for idx, label in enumerate(emotion_labels.keys())}

# Feature extraction
def extract_audio_features(file_path):
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.GeMAPSv01b,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
    features = smile.process_file(file_path)
    return features.values

# Load data
data_folder = "Emo-DB-database"
file_list = os.listdir(data_folder)

data = []
labels = []

for file_name in file_list:
    emotion_code = file_name[5]
    if emotion_code in emotion_labels:
        file_path = os.path.join(data_folder, file_name)
        features = extract_audio_features(file_path)
        data.append(features)
        labels.append(emotion_code)

data = np.vstack(data)
labels = np.array(labels)

# Preprocessing
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Save features and labels
with open('features.pkl', 'wb') as f:
    pickle.dump(data, f)
with open('labels.pkl', 'wb') as f:
    pickle.dump(labels, f)

# %% [markdown]
# ### training

# %%
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Emotion labels
emotion_labels = {
    'W': 'Anger',
    'L': 'Boredom',
    'E': 'Disgust',
    'A': 'Anxiety/Fear',
    'F': 'Happiness',
    'T': 'Sadness',
    'N': 'Neutral'
}
label_to_idx = {label: idx for idx, label in enumerate(emotion_labels.keys())}

# Load features and labels
with open('features.pkl', 'rb') as f:
    data = pickle.load(f)
with open('labels.pkl', 'rb') as f:
    labels = pickle.load(f)

# Convert labels to categorical
labels = np.array([label_to_idx[label] for label in labels])
labels = to_categorical(labels)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

def train_model(epochs, batch_size, learning_rate):
    # Create a feed-forward neural network
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        Dropout(0.5),
        Dense(32, activation='relu'),
        Dropout(0.5),
        Dense(len(emotion_labels), activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Test loss: {loss}, Test accuracy: {accuracy}")

    # Get predictions and convert back to original labels
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)
    idx_to_label = {idx: label for label, idx in label_to_idx.items()}
    y_pred_labels = np.array([idx_to_label[idx] for idx in y_pred_labels])
    y_test_labels = np.array([idx_to_label[idx] for idx in y_test_labels])

    print(classification_report(y_test_labels, y_pred_labels, target_names=emotion_labels.values()))



# Trry for different hyperparamters
train_model(epochs=20, batch_size=32, learning_rate=0.001)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 21ms/step - loss: 2.6355 - accuracy: 0.1766 - val_loss: 1.7515 - val_accuracy: 0.2791
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 2.2093 - accuracy: 0.1896 - val_loss: 1.5832 - val_accuracy: 0.4186
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.9584 - accuracy: 0.2805 - val_loss: 1.4749 - val_accuracy: 0.5581
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.7924 - accuracy: 0.3221 - val_loss: 1.4071 - val_accuracy: 0.6279
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.9296 - accuracy: 0.2831 - val_loss: 1.3573 - val_accuracy: 0.6744
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.7440 - accuracy: 0.3325 - val_loss: 1.3242 - val_accuracy: 0.6512
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.6536 - accuracy: 0.3688 - val_loss: 1.2954 - val_accuracy: 0.6512
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.6160 - accuracy: 0.3481 - val_loss: 1.2687 - val_accuracy: 0.6512
# Epoch 9/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.5716 - accuracy: 0.3948 - val_loss: 1.2404 - val_accuracy: 0.6512
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.6069 - accuracy: 0.3896 - val_loss: 1.2159 - val_accuracy: 0.6512
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.5360 - accuracy: 0.4156 - val_loss: 1.1864 - val_accuracy: 0.6512
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.4780 - accuracy: 0.4390 - val_loss: 1.1625 - val_accuracy: 0.6512
# Epoch 13/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.4764 - accuracy: 0.4545 - val_loss: 1.1317 - val_accuracy: 0.6512
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.4325 - accuracy: 0.4831 - val_loss: 1.0987 - val_accuracy: 0.6744
# Epoch 15/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.3826 - accuracy: 0.4338 - val_loss: 1.0709 - val_accuracy: 0.6744
# Epoch 16/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.3638 - accuracy: 0.4805 - val_loss: 1.0444 - val_accuracy: 0.6744
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.3288 - accuracy: 0.4727 - val_loss: 1.0229 - val_accuracy: 0.6512
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.3506 - accuracy: 0.4727 - val_loss: 1.0133 - val_accuracy: 0.6279
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.2971 - accuracy: 0.5117 - val_loss: 0.9960 - val_accuracy: 0.6512
# Epoch 20/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.2832 - accuracy: 0.5221 - val_loss: 0.9763 - val_accuracy: 0.6512
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2048 - accuracy: 0.5888
# Test loss: 1.2048426866531372, Test accuracy: 0.5887850522994995
# 4/4 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#        Anger       0.33      0.43      0.38        14
#      Boredom       1.00      0.17      0.29        12
#      Disgust       0.62      0.28      0.38        18
# Anxiety/Fear       0.65      0.85      0.74        20
#    Happiness       0.53      0.56      0.55        16
#      Sadness       0.82      1.00      0.90         9
#      Neutral       0.60      0.83      0.70        18
#
#     accuracy                           0.59       107
#    macro avg       0.65      0.59      0.56       107
# weighted avg       0.63      0.59      0.56       107

# %% [markdown]
# ## open smile with a very simple NN and f1 added

# %% [markdown]
# ## training

# %%
import os
import numpy as np
import opensmile
import pickle
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report



def f1_metric(y_true, y_pred):
    y_pred = tf.round(y_pred)
    tp = tf.reduce_sum(tf.cast(y_true * y_pred, 'float'), axis=0)
    tn = tf.reduce_sum(tf.cast((1 - y_true) * (1 - y_pred), 'float'), axis=0)
    fp = tf.reduce_sum(tf.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = tf.reduce_sum(tf.cast(y_true * (1 - y_pred), 'float'), axis=0)

    p = tp / (tp + fp + tf.keras.backend.epsilon())
    r = tp / (tp + fn + tf.keras.backend.epsilon())

    f1 = 2 * p * r / (p + r + tf.keras.backend.epsilon())
    f1 = tf.where(tf.math.is_nan(f1), tf.zeros_like(f1), f1)
    return tf.reduce_mean(f1)






# Emotion labels
emotion_labels = {
    'W': 'Anger',
    'L': 'Boredom',
    'E': 'Disgust',
    'A': 'Anxiety/Fear',
    'F': 'Happiness',
    'T': 'Sadness',
    'N': 'Neutral'
}
label_to_idx = {label: idx for idx, label in enumerate(emotion_labels.keys())}

# Load features and labels
with open('features.pkl', 'rb') as f:
    data = pickle.load(f)
with open('labels.pkl', 'rb') as f:
    labels = pickle.load(f)

# Convert labels to categorical
labels = np.array([label_to_idx[label] for label in labels])
labels = to_categorical(labels)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

def train_model(epochs, batch_size, learning_rate):
    # Create a feed-forward neural network
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        Dropout(0.5),
        Dense(32, activation='relu'),
        Dropout(0.5),
        Dense(len(emotion_labels), activation='softmax')
    ])

    # Compile the model
    #model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy', f1_metric])

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

    # Evaluate the model
    loss, accuracy, f1 = model.evaluate(X_test, y_test)
    print(f"Test loss: {loss}, Test accuracy: {accuracy}, Test F1 score: {f1}")

    # Get predictions and convert back to original labels
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)
    idx_to_label = {idx: label for label, idx in label_to_idx.items()}
    y_pred_labels = np.array([idx_to_label[idx] for idx in y_pred_labels])
    y_test_labels = np.array([idx_to_label[idx] for idx in y_test_labels])

    print(classification_report(y_test_labels, y_pred_labels, target_names=emotion_labels.values()))



# Trry for different hyperparamters
train_model(epochs=20, batch_size=32, learning_rate=0.001)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 23ms/step - loss: 2.3417 - accuracy: 0.1766 - f1_metric: 0.0705 - val_loss: 1.8071 - val_accuracy: 0.2791 - val_f1_metric: 0.0000e+00
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 2.0504 - accuracy: 0.2338 - f1_metric: 0.0945 - val_loss: 1.5730 - val_accuracy: 0.4419 - val_f1_metric: 0.0518
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.8356 - accuracy: 0.3143 - f1_metric: 0.1445 - val_loss: 1.4046 - val_accuracy: 0.6047 - val_f1_metric: 0.0646
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.7780 - accuracy: 0.3532 - f1_metric: 0.1625 - val_loss: 1.3125 - val_accuracy: 0.6512 - val_f1_metric: 0.0740
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.6620 - accuracy: 0.3870 - f1_metric: 0.1754 - val_loss: 1.2462 - val_accuracy: 0.6279 - val_f1_metric: 0.0821
# Epoch 6/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.6537 - accuracy: 0.3792 - f1_metric: 0.1789 - val_loss: 1.1966 - val_accuracy: 0.6744 - val_f1_metric: 0.0893
# Epoch 7/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.5437 - accuracy: 0.4519 - f1_metric: 0.1989 - val_loss: 1.1609 - val_accuracy: 0.6977 - val_f1_metric: 0.1464
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.5074 - accuracy: 0.4390 - f1_metric: 0.2330 - val_loss: 1.1337 - val_accuracy: 0.6977 - val_f1_metric: 0.1527
# Epoch 9/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.5426 - accuracy: 0.4390 - f1_metric: 0.2173 - val_loss: 1.1263 - val_accuracy: 0.6744 - val_f1_metric: 0.0992
# Epoch 10/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.4916 - accuracy: 0.4935 - f1_metric: 0.1965 - val_loss: 1.1114 - val_accuracy: 0.6977 - val_f1_metric: 0.0992
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.4675 - accuracy: 0.4701 - f1_metric: 0.2203 - val_loss: 1.0742 - val_accuracy: 0.6744 - val_f1_metric: 0.0992
# Epoch 12/20
# 13/13 [==============================] - 0s 7ms/step - loss: 1.3604 - accuracy: 0.4779 - f1_metric: 0.2645 - val_loss: 1.0277 - val_accuracy: 0.6744 - val_f1_metric: 0.1412
# Epoch 13/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.4366 - accuracy: 0.4623 - f1_metric: 0.2131 - val_loss: 1.0058 - val_accuracy: 0.6744 - val_f1_metric: 0.1518
# Epoch 14/20
# 13/13 [==============================] - 0s 7ms/step - loss: 1.3737 - accuracy: 0.4649 - f1_metric: 0.2415 - val_loss: 1.0008 - val_accuracy: 0.6512 - val_f1_metric: 0.1468
# Epoch 15/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.3177 - accuracy: 0.4961 - f1_metric: 0.2839 - val_loss: 0.9937 - val_accuracy: 0.6512 - val_f1_metric: 0.1754
# Epoch 16/20
# 13/13 [==============================] - 0s 7ms/step - loss: 1.3250 - accuracy: 0.5143 - f1_metric: 0.2971 - val_loss: 0.9781 - val_accuracy: 0.6512 - val_f1_metric: 0.2254
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 1.2742 - accuracy: 0.5299 - f1_metric: 0.2849 - val_loss: 0.9532 - val_accuracy: 0.6512 - val_f1_metric: 0.2254
# Epoch 18/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.2554 - accuracy: 0.5195 - f1_metric: 0.3009 - val_loss: 0.9229 - val_accuracy: 0.6512 - val_f1_metric: 0.2298
# Epoch 19/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.2269 - accuracy: 0.5662 - f1_metric: 0.3457 - val_loss: 0.8905 - val_accuracy: 0.6512 - val_f1_metric: 0.2449
# Epoch 20/20
# 13/13 [==============================] - 0s 6ms/step - loss: 1.2523 - accuracy: 0.5455 - f1_metric: 0.3342 - val_loss: 0.8728 - val_accuracy: 0.6512 - val_f1_metric: 0.2676
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0829 - accuracy: 0.6262 - f1_metric: 0.3380
# Test loss: 1.0828922986984253, Test accuracy: 0.6261682510375977, Test F1 score: 0.33803853392601013
# 4/4 [==============================] - 0s 0s/step
#               precision    recall  f1-score   support
#
#        Anger       0.60      0.43      0.50        14
#      Boredom       1.00      0.17      0.29        12
#      Disgust       1.00      0.17      0.29        18
# Anxiety/Fear       0.66      0.95      0.78        20
#    Happiness       0.68      0.81      0.74        16
#      Sadness       0.82      1.00      0.90         9
#      Neutral       0.45      0.83      0.59        18
#
#     accuracy                           0.63       107
#    macro avg       0.74      0.62      0.58       107
# weighted avg       0.73      0.63      0.58       107
